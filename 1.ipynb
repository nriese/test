# %% [markdown]
# # This is a notebook
#
# ## Section 1

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Let us make a plot

# %%
x = np.linspace(0, 50, 1000)
x *= np.cos(x)

pd.DataFrame({"x":x}).plot()
# Out:
# <AxesSubplot:>
